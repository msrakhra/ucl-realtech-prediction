# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()

csv_path_real = os.getenv("REAL_DATA_PATH")
csv_path_predicted = os.getenv("PREDICTED_DATA_PATH")

RHP = pd.read_csv(csv_path_real)

if csv_path_real is None:
    raise ValueError("DATA_CSV_PATH not set in .env file")

PHP = pd.read_csv(csv_path_predicted)

if csv_path_predicted is None:
    raise ValueError("DATA_CSV_PATH not set in .env file")


data_from = 2006
present = 2026
prediction_range = 5

time_period = list(range(data_from, present + prediction_range))

# %%
plt.figure(figsize = (10,8))

plf.clf()
plf.cla()

plt.plot(time_period,RHP, colour = 'blue', linestyle = '--', marker = 'o', linewidth = 2)
plt.plot(time_period,PHP,color = 'red', linestyle = '--', marker = 'o', linewidth = 2)

plt.title("Real vs Predicted House Prices")

plt.xlabel("Time Period (Years)")
plt.ylabel("House Prices(£)")

plt.legend(["Actual House Prices", "Predicted House Prices"])


plt.tight_layout()
plt.show()
